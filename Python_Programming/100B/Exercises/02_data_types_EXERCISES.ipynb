# %% [markdown]
# # Python Data Types — EXERCISES
#
# Teaching/practice notebook for beginner Python.

# %% [markdown]
# ## Exercise 1: Types
# Create one variable for each type: int, float, string, boolean, and None. Print each type.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Dynamic Typing
# Assign a number to `x`, print its type, then assign text to `x` and print its type again.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Number Conversion
# Convert the strings "25" and "3.14" to number types.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: String Indexing and Slicing
# Use a string variable and print the first character, last character, and a slice.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5: String Methods
# Use upper, replace, split, count, and find on one sentence.

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: Immutability
# Create a string and produce a modified version without changing the original directly.

# %%
# Your code here

# %% [markdown]
# ## Exercise 7: Booleans
# Create two comparisons and combine them using `and` and `or`.

# %%
# Your code here

# %% [markdown]
# ## Exercise 8: None
# Create a variable with `None`, then update it and test using `is None` and `is not None`.

# %%
# Your code here

# %% [markdown]
# ## Exercise 9: Tuple
# Create a tuple of four values and access the second value.

# %%
# Your code here

# %% [markdown]
# ## Exercise 10: List
# Create a list, append one item, insert one item, remove one item, then sort it.

# %%
# Your code here

# %% [markdown]
# ## Exercise 11: Set
# Create a set from a list with duplicates, then add and remove values.

# %%
# Your code here

# %% [markdown]
# ## Exercise 12: Dictionary
# Create a dictionary of students and grades. Add, update, and remove one entry.

# %%
# Your code here

# %% [markdown]
# ## Challenge
# Build a small contact book using a dictionary where names are keys and phone numbers are values.

# %%
# Your code here
