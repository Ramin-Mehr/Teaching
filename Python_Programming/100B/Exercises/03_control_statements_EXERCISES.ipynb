# %% [markdown]
# # Python Control Statements — EXERCISES
#
# Teaching/practice notebook for beginner Python.

# %% [markdown]
# ## Exercise 1: Sequential Flow
# Write three print statements that show the steps of making tea.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Basic If
# Create a variable `temperature`. Print "Hot" if it is greater than 30.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: If Else
# Create a variable `number`. Print whether it is positive or not positive.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: If Elif Else
# Print whether a number is positive, negative, or zero.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5: Logical Operators
# Create variables `age` and `has_id`. Print whether someone can enter a club.

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: Nested If
# Check whether a score is passing. If passing, check whether it is excellent.

# %%
# Your code here

# %% [markdown]
# ## Exercise 7: If Expression
# Use a one-line if expression to assign "adult" or "minor" based on age.

# %%
# Your code here

# %% [markdown]
# ## Exercise 8: While Loop
# Use a while loop to print numbers from 1 to 5.

# %%
# Your code here

# %% [markdown]
# ## Exercise 9: For Loop
# Use a for loop to print every item in a list of names.

# %%
# Your code here

# %% [markdown]
# ## Exercise 10: Range
# Print even numbers from 2 to 20 using range.

# %%
# Your code here

# %% [markdown]
# ## Exercise 11: Break
# Loop from 1 to 10 and stop when the number is 6.

# %%
# Your code here

# %% [markdown]
# ## Exercise 12: Continue
# Loop from 1 to 10 but skip number 5.

# %%
# Your code here

# %% [markdown]
# ## Exercise 13: Pass
# Write an if/else block where the else block uses `pass`.

# %%
# Your code here

# %% [markdown]
# ## Challenge: Login Attempts
# Create a simple login attempt loop. Stop when password is correct or attempts reach 3.

# %%
# password = "python123"
# attempts = 0
# Your code here
