# %% [markdown]
# # 10 - Code Style
#
# **Type:** Exercise notebook
#
# Prepared for bachelor-level Python programming students.

# %% [markdown]
# ## Exercise 1
# Fix the spacing and naming style in this code.

# %%
# Improve this code
x=10
y=20
print(x+y)

# %% [markdown]
# ## Exercise 2
# Rewrite this function using a better name, docstring, and type hints.

# %%
def f(a,b):
    return a*b

# %% [markdown]
# ## Exercise 3
# Create examples of good variable, constant, function, and class names.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4
# Write a block comment and an inline comment correctly.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5
# Use `join()` to combine a list of words into one sentence.

# %%
words = ["Python", "is", "easy", "to", "read"]
# Your code here

# %% [markdown]
# ## Exercise 6
# Refactor a short piece of non-Pythonic code into clearer Python code.

# %%
# Your code here
