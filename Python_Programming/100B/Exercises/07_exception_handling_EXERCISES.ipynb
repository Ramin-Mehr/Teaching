# %% [markdown]
# # 07 - Exception Handling
#
# **Type:** Exercise notebook
#
# Prepared for bachelor-level Python programming students.

# %% [markdown]
# ## Exercise 1
# Ask for two numbers and divide them. Handle division by zero.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2
# Convert a string to an integer. Use `try-except` to handle invalid input.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3
# Write `check_password(password)` that raises `ValueError` if the password has fewer than 8 characters.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4
# Use `else` and `finally` in a file-writing example.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5
# Create a custom exception called `InvalidGradeException`. Raise it if a grade is outside 0 to 100.

# %%
# Your code here
