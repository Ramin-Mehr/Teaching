# %% [markdown]
# # Python Expressions, Operators, Variables — EXERCISES
#
# Teaching/practice notebook for beginner Python.

# %% [markdown]
# ## Exercise 1: Expressions
# Calculate the result of `8 * 7 + 10`.

# %%
# Write your answer here

# %% [markdown]
# ## Exercise 2: Precedence
# Create two expressions where parentheses change the result.

# %%
# Example: print(...)

# %% [markdown]
# ## Exercise 3: Assignment Operators
# Start with `score = 20`, add 10, then multiply by 3.

# %%
score = 20
# Continue here

# %% [markdown]
# ## Exercise 4: Meaningful Variables
# Create variables for a student name, age, and grade. Print a sentence using them.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5: Comparisons and Logic
# Create variables `age` and `has_ticket`. Print whether the person can enter an event.

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: Membership
# Create a list of course names and check whether "Python" is inside it.

# %%
# Your code here

# %% [markdown]
# ## Exercise 7: Built-in Functions
# Use `abs`, `max`, `min`, and `round` in separate examples.

# %%
# Your code here

# %% [markdown]
# ## Exercise 8: Comments
# Write three lines of code and add helpful comments.

# %%
# Your code here

# %% [markdown]
# ## Challenge
# Create a small program that calculates the final price after discount.

# %%
# price = ...
# discount_percent = ...
# final_price = ...
