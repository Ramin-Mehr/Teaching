# %% [markdown]
# # 08 - File Handling
#
# **Type:** Exercise notebook
#
# Prepared for bachelor-level Python programming students.

# %% [markdown]
# ## Exercise 1
# Create a file called `notes.txt` and write three lines into it.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2
# Read `notes.txt` and print each line without extra newline spaces.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3
# Append two new lines to `notes.txt`.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4
# Use `pathlib` to check if `notes.txt` exists.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5
# Create a file with numbers from 1 to 10, then read the file and calculate the total.

# %%
# Your code here

# %% [markdown]
# ## Exercise 6
# Rename a file and then delete it using `pathlib`.

# %%
# Your code here
