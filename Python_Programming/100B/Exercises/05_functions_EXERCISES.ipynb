# %% [markdown]
# # 05 - Functions: Exercise Notebook
#
# Complete the exercises below. Write your code in the empty cells.

# %% [markdown]
# ## Exercise 1: Basic Function
# Create a function called `say_hello` that prints `Hello, Python!`.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 2: Function with Parameter
# Create a function called `welcome_student(name)` that prints a welcome message.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 3: Return a Value
# Create a function `multiply(a, b)` that returns the product of two numbers.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 4: Factorial
# Write a function `factorial(n)` using a loop.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 5: Default Parameter
# Create a function `introduce(name, university="GISMA")`.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 6: Named Arguments
# Create a function with parameters `name`, `age`, and `city`. Call it using named arguments in a different order.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 7: *args
# Create a function `average(*numbers)` that returns the average of all numbers.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 8: **kwargs
# Create a function that prints all key-value pairs passed as keyword arguments.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 9: Lambda
# Create a lambda function that calculates the square of a number.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 10: Recursion
# Write a recursive function to calculate factorial.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 11: Scope
# Create a global variable and a function that prints it. Then create a local variable inside another function.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 12: Higher-Order Function
# Create a function `apply_discount(price, discount_function)` and pass another function to calculate the discount.

# %%
# Write your code here

# %% [markdown]
# ## Challenge Exercise
# Create a small calculator using functions: `add`, `subtract`, `multiply`, and `divide`.

# %%
# Write your code here
