# %% [markdown]
# # 09 - Modules and Packages
#
# **Type:** Exercise notebook
#
# Prepared for bachelor-level Python programming students.

# %% [markdown]
# ## Exercise 1
# Import the `math` module and calculate the square root of 144.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2
# Import only `randint` from `random` and generate a number between 1 and 100.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3
# Create a file `calculator.py` with functions `add`, `subtract`, `multiply`, and `divide`. Import and use it.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4
# Use `dir()` on the `datetime` module and print the first 15 items.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5
# Create a script file that uses `if __name__ == '__main__':`.

# %%
# Your code here
