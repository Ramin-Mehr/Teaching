# %% [markdown]
# # 06 - Classes: Exercise Notebook
#
# Complete the exercises below. Write your code in the empty cells.

# %% [markdown]
# ## Exercise 1: Empty Class
# Create an empty class called `Book` and create one object from it.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 2: Constructor
# Create a `Book` class with `title` and `author` attributes.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 3: Method
# Add a method called `show_info()` that prints the book title and author.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 4: `__str__` Method
# Add a `__str__` method to return a readable string for a book.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 5: Object References
# Create one object, assign it to another variable, modify one attribute, and check both variables.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 6: Class Variable
# Create a `Student` class with a class variable `count` that counts the number of students.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 7: Class Method
# Add a class method that returns the number of created students.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 8: Static Method
# Create a class `Temperature` with a static method `celsius_to_fahrenheit(celsius)`.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 9: Getter and Setter
# Create a `Person` class with private `_age`, `get_age`, and `set_age` methods. Validate that age is between 1 and 119.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 10: Property
# Rewrite the previous exercise using `@property` and `@age.setter`.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 11: Intrinsic Attributes
# Create an object and print its `__dict__`, `__class__`, and the class `__name__`.

# %%
# Write your code here

# %% [markdown]
# ## Challenge Exercise
# Create a `BankAccount` class with owner, balance, deposit, withdraw, and `__str__`.

# %%
# Write your code here
